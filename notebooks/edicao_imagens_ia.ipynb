# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrosouzag/edicao-imagens-ia/blob/main/edicao_imagens_ia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto de Edição de Imagens com IA
#
# Configuração e teste do ambiente computacional.

# %%
print("Teste")
# Out:
# Teste

# %%
import sys

print("Versão do Python:", sys.version)
# Out:
# Versão do Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
import torch

print("Versão do PyTorch:", torch.__version__)
print("GPU disponível:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %%
# numpy é usada para trabalhar com matrizes e cálculos numéricos
import numpy as np

# pandas é usada para organizar dados em tabelas
import pandas as pd

# matplotlib é usada para mostrar gráficos e imagens
import matplotlib.pyplot as plt

# pillow é usada para abrir, salvar e modificar imagens
from PIL import Image

# opencv é uma biblioteca de visão computacional
# usada para processar e editar imagens
import cv2

print("Bibliotecas importadas com sucesso.")
